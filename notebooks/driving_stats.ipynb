# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
pga_driving_stats = pd.read_csv(r"C:\Users\Jeremy\Documents\NSS DA 2024\captsone\data\comparable\driving\pga_driving_2022_2023.csv")

# %%
pga_driving_stats = pga_driving_stats.drop(columns = ['MOVEMENT', 'PLAYER_ID'])
pga_driving_stats.head()
# Out:
#    RANK            PLAYER    AVG  TOTAL DISTANCE  TOTAL DRIVES
# 0     1      Rory McIlroy  326.3           41771           128
# 1     2       Peter Kuest  321.7           29594            92
# 2     3  Brandon Matthews  321.3           37915           118
# 3     4     Cameron Champ  317.9           49589           156
# 4     5  Nicolai Hojgaard  317.7           29227            92

# %%
sns.set_theme(style="darkgrid")
plt.figure(figsize=(15, 10))
sns.boxplot(data = pga_driving_stats, x = 'AVG', palette="crest")
plt.xlabel("YARDS")
plt.title("PGA TOUR DRIVE DISTANCE AVERAGES 2022-2023");

# %%
## plt.figure(figsize=(20, 15))
## ax = sns.barplot(pga_driving_stats.head(25), x="PLAYER", y="AVG",palette="crest")
## plt.xticks(rotation=90)
## for container in ax.containers:
##     ax.bar_label(container, fmt='%.1f', padding=0.1, rotation=45)
## plt.grid()
## plt.show();

# %%
## plt.figure(figsize=(20, 15))
## ax = sns.barplot(pga_driving_stats.tail(25), x="PLAYER", y="AVG",palette="crest")
## plt.xticks(rotation=90)
## for container in ax.containers:
##     ax.bar_label(container, fmt='%.1f', padding=0.5, rotation=45)
## plt.grid()
## plt.show();

# %%
pga_driving_stats_describe = pga_driving_stats['AVG'].describe().reset_index()
pga_driving_stats_describe
# Out:
#    index         AVG
# 0  count  193.000000
# 1   mean  300.608808
# 2    std    8.921648
# 3    min  271.500000
# 4    25%  295.200000
# 5    50%  300.100000
# 6    75%  306.200000
# 7    max  326.300000

# %%
am_driving_stats = pd.read_csv(r"C:/Users/Jeremy/Documents/NSS DA 2024/captsone/data/comparable/driving/am_driving_distance_by_handicap.csv")

# %%
am_driving_stats.columns = ['Handicap', 'AVG YRDS']
am_driving_stats
# Out:
#     Handicap  AVG YRDS
# 0          0       261
# 1          1       257
# 2          2       254
# 3          3       250
# 4          4       247
# 5          5       243
# 6          6       240
# 7          7       237
# 8          8       234
# 9          9       232
# 10        10       229
# 11        11       225
# 12        12       223
# 13        13       220
# 14        14       218
# 15        15       216
# 16        16       213
# 17        17       210
# 18        18       208
# 19        19       206
# 20        20       204
# 21        21       202
# 22        22       200
# 23        23       198
# 24        24       197
# 25        25       196

# %%
sns.boxplot(data = am_driving_stats, x = 'AVG YRDS', palette="crest");

# %%
## plt.figure(figsize=(15, 10))
## ax = sns.barplot(am_driving_stats, x="Handicap", y="AVG YRDS",palette="crest")
## plt.xticks(rotation=90)
## for container in ax.containers:
##    ax.bar_label(container, fmt='%.f', padding=3, rotation=45)
## plt.grid()
## plt.xlabel("HANDICAP")
## plt.ylabel("AVG YARDS")
## plt.title("AMATEUR DRIVING DISTANCE AVERAGES");
## plt.show();

# %%
sns.set_theme(style="darkgrid")
plt.figure(figsize=(15, 10))
sns.boxplot(data = am_driving_stats, x = 'AVG YRDS', palette="BuGn")
plt.xlabel("YARDS")
plt.title("AMATEUR DRIVING DISTANCE AVERAGES");

# %%
am_driving_stats_describe = am_driving_stats['AVG YRDS'].describe()
am_driving_stats_describe.reset_index()
# Out:
#    index    AVG YRDS
# 0  count   26.000000
# 1   mean  223.846154
# 2    std   20.200381
# 3    min  196.000000
# 4    25%  206.500000
# 5    50%  221.500000
# 6    75%  239.250000
# 7    max  261.000000
