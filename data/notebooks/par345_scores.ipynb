# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
am_par_3_scores = pd.read_csv(r"C:\Users\Jeremy\Documents\NSS DA 2024\captsone\data\comparable\par3_4_5 scoring\am-pa3_scores.csv")

# %%
am_par_3_scores
# Out:
#    Handicap  Average Score
# 0         0           3.16
# 1         5           3.36
# 2        10           3.60
# 3        15           3.83
# 4        20           4.00
# 5        25           4.19

# %%
am_par_3_scores.to_csv("am_par_3_scores_python.csv")

# %%
sns.set_theme(style="darkgrid")
plt.figure(figsize=(15, 10))
ax = sns.barplot(am_par_3_scores, x="Handicap", y="Average Score", palette="crest")
plt.xticks(rotation=30)
for container in ax.containers:
    ax.bar_label(container, fmt='%.2f', padding=0.5)
plt.grid("light")
plt.xlabel("HANDICAP")
plt.ylabel("AVERAGE SCORE")
plt.title("AMATEURS AVG SCORE ON PAR 3 HOLES")
plt.show();

# %%
sns.set_theme(style="darkgrid")
plt.figure(figsize=(15, 10))
sns.boxplot(data = am_par_3_scores, x="Average Score", palette="BuGn")
plt.xlabel("BIRDIES PER ROUND")
plt.title("AMATEUR BIRDIES PER ROUND AVERAGES");

# %%
am_par_4_scores = pd.read_csv(r"C:\Users\Jeremy\Documents\NSS DA 2024\captsone\data\comparable\par3_4_5 scoring\am_par4_scores.csv")

# %%
am_par_4_scores
# Out:
#    Handicap  Average Score
# 0         0           4.09
# 1         5           4.43
# 2        10           4.67
# 3        15           5.05
# 4        20           5.31
# 5        25           5.87

# %%
sns.set_theme(style="darkgrid")
plt.figure(figsize=(15, 10))
ax = sns.barplot(am_par_4_scores, x="Handicap", y="Average Score", palette="crest")
plt.xticks(rotation=30)
for container in ax.containers:
    ax.bar_label(container, fmt='%.2f', padding=0.5)
plt.grid("light")
plt.xlabel("HANDICAP")
plt.ylabel("AVERAGE SCORE")
plt.title("AMATEURS AVG SCORE ON PAR 4 HOLES")
plt.show();

# %%
am_par_5_scores = pd.read_csv(r"C:\Users\Jeremy\Documents\NSS DA 2024\captsone\data\comparable\par3_4_5 scoring\am_par5_scoring.csv")

# %%
am_par_5_scores
# Out:
#    Handicap  Average Score
# 0         0           4.76
# 1         5           5.17
# 2        10           5.53
# 3        15           5.91
# 4        20           6.23
# 5        25           6.98

# %%
sns.set_theme(style="darkgrid")
plt.figure(figsize=(15, 10))
ax = sns.barplot(am_par_5_scores, x="Handicap", y="Average Score", palette="crest")
plt.xticks(rotation=30)
for container in ax.containers:
    ax.bar_label(container, fmt='%.2f', padding=0.5)
plt.grid("light")
plt.xlabel("HANDICAP")
plt.ylabel("AVERAGE SCORE")
plt.title("AMATEURS AVG SCORE ON PAR 5 HOLES")
plt.show();

# %%
pga_par_3_scores = pd.read_csv(r"C:\Users\Jeremy\Documents\NSS DA 2024\captsone\data\comparable\par3_4_5 scoring\pga par 3 scoring.csv")

# %%
pga_par_3_scores.to_csv("pga_par_3_scores_python.csv")

# %%
pga_par_3_scores = pga_par_3_scores.drop(columns = ['MOVEMENT', 'PLAYER_ID'])

# %%
pga_par_3_scores
# Out:
#      RANK            PLAYER   AVG  TOTAL STROKES  TOTAL HOLES
# 0       1       Peter Kuest  2.93            527          180
# 1       2          Max Homa  2.94           1017          346
# 2       3         Eric Cole  2.95           1541          523
# 3       3          Jon Rahm  2.95            850          288
# 4       5  Nicolai Hojgaard  2.96            575          194
# ..    ...               ...   ...            ...          ...
# 188   186     Trey Mullinax  3.14            899          286
# 189   186    Martin Trainer  3.14            794          253
# 190   191   Matthias Schwab  3.15           1321          419
# 191   192  Brandon Matthews  3.18            767          241
# 192   193       Brent Grant  3.20           1090          341
#
# [193 rows x 5 columns]

# %%
pga_par_3_scores['AVG'].describe()
# Out:
# count    193.000000
# mean       3.048135
# std        0.045788
# min        2.930000
# 25%        3.010000
# 50%        3.040000
# 75%        3.080000
# max        3.200000
# Name: AVG, dtype: float64

# %%
sns.set_theme(style="darkgrid")
plt.figure(figsize=(15, 10))
sns.boxplot(data = pga_par_3_scores, x = 'AVG', palette="crest")
plt.grid("light")
plt.xlabel("AVG SCORE")
plt.title("PGA TOUR AVG SCORES ON PAR 3 HOLES 2022-2023");

# %%
pga_par_4_scores = pd.read_csv(r"C:\Users\Jeremy\Documents\NSS DA 2024\captsone\data\comparable\par3_4_5 scoring\pga par 4 scoring.csv")

# %%
pga_par_4_scores = pga_par_4_scores.drop(columns = ['MOVEMENT', 'PLAYER_ID'])

# %%
pga_par_4_scores.head()
# Out:
#    RANK             PLAYER   AVG  TOTAL STROKES  TOTAL HOLES
# 0     1       Ludvig Åberg  3.91           2102          538
# 1     1  Scottie Scheffler  3.91           3754          960
# 2     3    Patrick Cantlay  3.93           3087          786
# 3     4     Viktor Hovland  3.94           3780          959
# 4     5     Denny McCarthy  3.95           4297         1089

# %%
pga_par_4_scores.to_csv("pga_par_4_scores_python.csv")

# %%
pga_par_4_scores['AVG'].describe()
# Out:
# count    193.000000
# mean       4.015078
# std        0.035504
# min        3.910000
# 25%        3.990000
# 50%        4.020000
# 75%        4.030000
# max        4.140000
# Name: AVG, dtype: float64

# %%
sns.set_theme(style="darkgrid")
plt.figure(figsize=(15, 10))
sns.boxplot(data = pga_par_4_scores, x = 'AVG', palette="crest")
plt.grid("light")
plt.xlabel("AVG SCORE")
plt.title("PGA TOUR AVG SCORES ON PAR 4 HOLES 2022-2023");

# %%
pga_par_5_scores = pd.read_csv(r"C:\Users\Jeremy\Documents\NSS DA 2024\captsone\data\comparable\par3_4_5 scoring\pga par 5 scoring.csv")

# %%
pga_par_5_scores = pga_par_5_scores.drop(columns = ['MOVEMENT', 'PLAYER_ID'])

# %%
pga_par_5_scores.head()
# Out:
#    RANK             PLAYER   AVG  TOTAL STROKES  TOTAL HOLES
# 0     1       Ludvig Åberg  4.44            711          160
# 1     1    Patrick Cantlay  4.44            977          220
# 2     3           Jon Rahm  4.46           1000          224
# 3     3  Scottie Scheffler  4.46           1177          264
# 4     5         Sungjae Im  4.47           1403          314

# %%
pga_par_5_scores.to_csv("pga_par_5_scores_python.csv")

# %%
sns.set_theme(style="darkgrid")
plt.figure(figsize=(15, 10))
sns.boxplot(data = pga_par_5_scores, x = 'AVG', palette="crest")
plt.grid("light")
plt.xlabel("AVG SCORE")
plt.title("PGA TOUR AVG SCORES ON PAR 5 HOLES 2022-2023");

# %%
pga_par5_describe = pga_par_5_scores['AVG'].describe().reset_index()
pga_par5_describe
# Out:
#    index         AVG
# 0  count  193.000000
# 1   mean    4.615130
# 2    std    0.061042
# 3    min    4.440000
# 4    25%    4.580000
# 5    50%    4.620000
# 6    75%    4.660000
# 7    max    4.790000
